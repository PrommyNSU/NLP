# %%
import csv
import pandas as pd

df = pd.read_csv('amazon_reviews_us_Shoes_v1_00.tsv',  delimiter='\t', error_bad_lines=False, low_memory=False, nrows=200)

df.head(6)
# Out:
#   marketplace  customer_id       review_id  product_id  product_parent  \
# 0          US     18069663  R3P2HIOQCIN5ZU  B000XB31C0       265024781
# 1          US     16251825  R12VVR0WH5Q24V  B00CFYZH5W       259035853
# 2          US     20381037   RNCCKB6TV5EEF  B00S8JNN3Q       666066660
# 3          US       108364  R2NZXYIVCGB13W  B00XFBPOQG       448483263
# 4          US     45449350  R2EQ1TG9IT3OEQ  B00SW64Y9W         7853171
# 5          US     19324665  R1WXA9JSC2H1U1  B011F9E6LI        14311457
#
#                                        product_title product_category  \
# 0  Minnetonka Men's Double Deerskin Softsole Mocc...            Shoes
# 1                        Teva Men's Pajaro Flip-Flop            Shoes
# 2                   Anne Klein Perfect Pair Wristlet            Shoes
# 3          adidas Men's 10K Lifestyle Runner Sneaker            Shoes
# 4  OverBling Sneakers for Men Casual Men Shoes Ge...            Shoes
# ...

# %%
df.head()
# Out:
#   marketplace  customer_id       review_id  product_id  product_parent  \
# 0          US     18069663  R3P2HIOQCIN5ZU  B000XB31C0       265024781
# 1          US     16251825  R12VVR0WH5Q24V  B00CFYZH5W       259035853
# 2          US     20381037   RNCCKB6TV5EEF  B00S8JNN3Q       666066660
# 3          US       108364  R2NZXYIVCGB13W  B00XFBPOQG       448483263
# 4          US     45449350  R2EQ1TG9IT3OEQ  B00SW64Y9W         7853171
#
#                                        product_title product_category  \
# 0  Minnetonka Men's Double Deerskin Softsole Mocc...            Shoes
# 1                        Teva Men's Pajaro Flip-Flop            Shoes
# 2                   Anne Klein Perfect Pair Wristlet            Shoes
# 3          adidas Men's 10K Lifestyle Runner Sneaker            Shoes
# 4  OverBling Sneakers for Men Casual Men Shoes Ge...            Shoes
#
#    star_rating  helpful_votes  total_votes vine verified_purchase  \
# ...

# %%
df.head(29)
# Out:
#    marketplace  customer_id       review_id  product_id  product_parent  \
# 0           US     18069663  R3P2HIOQCIN5ZU  B000XB31C0       265024781
# 1           US     16251825  R12VVR0WH5Q24V  B00CFYZH5W       259035853
# 2           US     20381037   RNCCKB6TV5EEF  B00S8JNN3Q       666066660
# 3           US       108364  R2NZXYIVCGB13W  B00XFBPOQG       448483263
# 4           US     45449350  R2EQ1TG9IT3OEQ  B00SW64Y9W         7853171
# 5           US     19324665  R1WXA9JSC2H1U1  B011F9E6LI        14311457
# 6           US     50073594  R12ENYLFGGNWRV  B00HAUP1OI       264821602
# 7           US     21706057  R2R07E5PNXEUO5  B00L1RKOKW       767118055
# 8           US     13708216  R27BA52AKWMWN3  B005WA9MSE       813856438
# 9           US     40542649   RLF8DOID2KD5O  B00BEYQI5C       661491213
# 10          US     13409446  R369CEXHXHC6NQ  B00EYAFTCQ       332158165
# 11          US      9451727  R171PPIJXFONVI  B00I0QHY32        49243908
# ...

# %%
df_prod=df.groupby(['product_category'])
df_prod

# %%
df.tail(1)
# Out:
#     marketplace  customer_id       review_id  product_id  product_parent  \
# 199          US     46510269  R1IPTXTRRWN9MS  B00506CXJU       978462837
#
#                              product_title product_category  star_rating  \
# 199  Sanita Men's Professional Cabrio Clog            Shoes            1
#
#      helpful_votes  total_votes vine verified_purchase  \
# 199              3            3    N                 Y
#
#                         review_headline  \
# 199  Service was not very nice about it
#
#                                            review_body review_date
# 199  The sole broke in one shift. And by broke I me...  2015-08-31

# %%
df.iloc[96]['product_parent']
# Out:
# 182865605

# %%
for i in range(0,200):
    reviews=df.iloc[i]['review_body']
    print(reviews)
# Out:
# Do not buy: really didn't start to wear them until May of 2016. Junk, they are falling apart. The outer sole is so thin that although I wear them almost completely in the house on rugs the inner padding is showing through in the heel. My previous pair from the same company lasted 5 years before I threw them out.  I'm sorry I didn't wear them more often when I first got them as I would have returned them immediately
# provides great cushion as well as archsupport
# It's perfect if you need something small for cell phone, and few items.
# Getting what u see
# small
# My 13 year old son loved these shoes excellent quality service and on time for his Birthday !!!
# ...

# %%
df.loc[199]['review_body']
# Out:
# 'The sole broke in one shift. And by broke I mean I had a chunk fall off. Service was not very nice about it either'

# %%
df['marketplace'].dtype
# Out:
# dtype('O')

# %%
df['customer_id'].dtype
# Out:
# dtype('int64')

# %%
df['review_id'].dtype
# Out:
# dtype('O')

# %%
df['product_id'].dtype
# Out:
# dtype('O')

# %%
df['review_body']
# Out:
# 0      Do not buy: really didn't start to wear them u...
# 1          provides great cushion as well as archsupport
# 2      It's perfect if you need something small for c...
# 3                                     Getting what u see
# 4                                                  small
# 5      My 13 year old son loved these shoes excellent...
# 6      Ok, I have been searching for shoes to replace...
# 7      I went a full size down and they fit better bu...
# 8      I would have to say this is boot is very good ...
# 9                                The size is misleading!
# 10                     These shoes are very comfortable.
# 11                                 I love these sandals!
# 12     Good quality shoes. Great for casual or busine...
# 13     My daughter really likes those shoes. They are...
# 14                                           It's okay .
# 15     Love these shoes! Perfect fit, very comfortabl...
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.T
# Out:
#                                                                  0    \
# marketplace                                                       US
# customer_id                                                 18069663
# review_id                                             R3P2HIOQCIN5ZU
# product_id                                                B000XB31C0
# product_parent                                             265024781
# product_title      Minnetonka Men's Double Deerskin Softsole Mocc...
# product_category                                               Shoes
# star_rating                                                        1
# helpful_votes                                                      0
# total_votes                                                        0
# vine                                                               N
# verified_purchase                                                  Y
# review_headline                                                    .
# ...
